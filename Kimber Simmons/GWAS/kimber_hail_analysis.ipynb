# %%
import hail as hl
hl.init(spark_conf={'spark.driver.memory': '12g'})
# Out:
# Running on Apache Spark version 3.1.2
# SparkUI available at http://192.168.0.56:4041
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.70-5bb98953a4a7
# LOGGING: writing to /Users/timvigers/GitHub/CHCO-Code/Petter Bjornstad/Pima/master_data/tim_merge/hail-20210702-1447-0.2.70-5bb98953a4a7.log

# %%
from hail.plot import show
from pprint import pprint
hl.plot.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
ds = hl.import_plink(bed='/Users/timvigers/Dropbox/Work/Kimber Simmons/GWAS/Data_Raw/Simmons_MEGA1_Deliverable_06142019/raw_files/Simmons_Custom_MEGA_Analysi_03012019_removeKnownFails.bed',
                     bim='/Users/timvigers/Dropbox/Work/Kimber Simmons/GWAS/Data_Raw/Simmons_MEGA1_Deliverable_06142019/raw_files/Simmons_Custom_MEGA_Analysi_03012019_removeKnownFails.bim',
                     fam='/Users/timvigers/Dropbox/Work/Kimber Simmons/GWAS/Data_Raw/Simmons_MEGA1_Deliverable_06142019/raw_files/Simmons_Custom_MEGA_Analysi_03012019_removeKnownFails.fam',
                     reference_genome='GRCh38',skip_invalid_loci=True)
# Out:
# 2021-07-02 14:47:35 Hail: INFO: Found 771 samples in fam file.
# 2021-07-02 14:47:35 Hail: INFO: Found 1940188 variants in bim file.

# %%
mt = hl.sample_qc(ds)
p = hl.plot.histogram(mt.sample_qc.call_rate, range=(.88,1), legend='Call Rate')
show(p)
# Out:
#   <div class="bk-root" id="e1bc280d-c10f-4932-a5b6-e23ad4c6544a" data-root-id="1002"></div>
