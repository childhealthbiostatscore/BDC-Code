# %%
import pandas as pd

# %%
df = pd.read_excel("/Users/timvigers/metabolomics/XCMS-diffreport-MultiClass-positive.xlsx")
print(df)
# Out:
#       featureidx      name       mzmed       mzmin       mzmax     rtmed  \
# 0              1  M441T1_2  441.074615  441.074143  441.075017  0.694086
# 1              2  M221T1_1  220.557457  220.557293  220.557712  0.690347
# 2              3  M509T1_2  509.062210  509.061633  509.062951  0.670209
# 3              4  M383T1_2  383.115892  383.115620  383.116257  0.695663
# 4              5  M443T1_3  443.071439  443.070856  443.072130  0.692848
# ...          ...       ...         ...         ...         ...       ...
# 4489        4490  M295T1_6  295.102438  295.102151  295.102640  1.125857
# 4490        4491    M429T1  428.827285  428.826832  428.827838  0.652351
# 4491        4492    M466T2  466.316340  466.315726  466.316750  1.944914
# 4492        4493    M473T3  473.344823  473.343189  473.345383  2.643837
# 4493        4494    M541T3  541.450247  541.445807  541.450835  3.029893
#
#          rtmin     rtmax  npeaks  control.pos  ...     F86.2.41.  \
# ...

# %%
df.columns
# Out:
# Index(['featureidx', 'name', 'mzmed', 'mzmin', 'mzmax', 'rtmed', 'rtmin',
#        'rtmax', 'npeaks', 'control.pos', 'T1D.pos', 'CV', 'pvalue', 'qvalue',
#        'control.pos.mean', 'T1D.pos.mean', 'control.pos.SD', 'T1D.pos.SD',
#        'maxint', 'postHoc', 'F86.2.51.', 'F86.2.52.', 'F86.2.53.', 'F86.2.54.',
#        'F86.2.55.', 'F86.2.56.', 'F86.2.57.', 'F86.2.58.', 'F86.2.59.',
#        'F86.2.60.', 'F86.2.61.', 'F86.2.62.', 'F86.2.63.', 'F86.2.64.',
#        'F86.2.65.', 'F86.2.66.', 'F86.2.67.', 'F86.2.68.', 'F86.2.69.',
#        'F86.2.70.', 'F86.2.01.', 'F86.2.02.', 'F86.2.03.', 'F86.2.04.',
#        'F86.2.05.', 'F86.2.06.', 'F86.2.07.', 'F86.2.08.', 'F86.2.09.',
#        'F86.2.10.', 'F86.2.11.', 'F86.2.12.', 'F86.2.13.', 'F86.2.14.',
#        'F86.2.15.', 'F86.2.16.', 'F86.2.17.', 'F86.2.18.', 'F86.2.19.',
#        'F86.2.20.', 'F86.2.21.', 'F86.2.22.', 'F86.2.23.', 'F86.2.24.',
#        'F86.2.25.', 'F86.2.26.', 'F86.2.27.', 'F86.2.28.', 'F86.2.29.',
# ...
